# %% [markdown]
# <a href="https://colab.research.google.com/github/yasuhisasugiura-crypto/PARC2026_pre/blob/main/Colab_%E3%81%AE%E5%AE%9A%E6%9C%9F%E8%B3%BC%E5%85%A5%E3%82%92%E6%9C%80%E5%A4%A7%E9%99%90%E3%81%AB%E6%B4%BB%E7%94%A8%E3%81%99%E3%82%8B_%E3%81%AE%E3%82%B3%E3%83%94%E3%83%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab の定期購入を最大限に活用する

# %% [markdown]
# # Google Colab が VS Code で利用可能になりました。
# ![logo.webp](data:image/webp;base64,...)
#
# Visual Studio Code 用の新しい <a href="https://marketplace.visualstudio.com/items?itemName=Google.colab">Google Colab 拡張機能</a>をお試しください。数回クリックするだけで起動して使用できます。
#
# *  VS Code で &#91;<strong><em>拡張機能</em></strong>&#93; ビューを開き、「Google Colab」を検索してインストールします。
# *  ローカル ワークスペースで <code>.ipynb</code> ノートブック ファイルを作成または開いて、セルを実行するか、右上にある &#91;<strong><em>カーネルを選択</em></strong>&#93; ボタンをクリックして、カーネル セレクタを開きます。
# *  &#91;<strong><em>Colab</em></strong>&#93; をクリックし、目的のランタイムを選択して Google アカウントでログインすれば、準備完了です。
#
# 詳しくは、<a href="https://developers.googleblog.com/google-colab-is-coming-to-vs-code">こちらのお知らせブログ</a>をご覧ください。

# %% [markdown]
# # Access Popular LLMs via Google-Colab-AI Without an API Key

# %% [markdown]
# Users with Colab's paid plans have free access to most popular LLMs via google-colab-ai Python library. For more details, refer to the [getting started with google colab ai](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb).

# %%
from google.colab import ai
response = ai.generate_text("What is the capital of France?")
print(response)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## より速い GPU
#
# <p>Colab の有料プランのいずれかを購入されたユーザーは、より高速な GPU とより多くのメモリをご利用いただけます。ノートブックの GPU 設定は、メニューの <code>&#91;ランタイム&#93; &gt; &#91;ランタイムのタイプを変更&#93;</code> で、複数のアクセラレータ オプションから選択してアップグレードできます。</p>
# <p>Colab の料金がかからないバージョンでは、Nvidia の T4 GPU を、提供状況に応じて割り当て制限内で利用できます。</p>
#
# 次のセルを実行することで、どの GPU が割り当てられているかをいつでも確認できます。以下のコードセルを実行して「Not connected to a GPU」と表示された場合、メニューで <code>&#91;ランタイム&#93; &gt; &#91;ランタイムのタイプを変更&#93;</code> に移動して GPU アクセラレータを有効にすれば、ランタイムを変更できます。その後、コードセルを再実行します。

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %% [markdown]
# ノートブックで GPU を使用するには、メニューで <code>&#91;ランタイム&#93; &gt; &#91;ランタイムのタイプを変更&#93;</code> を選択後、ハードウェア アクセラレータをご希望のオプションに設定します。

# %% [markdown]
# ## より多くのメモリ
#
# Colab の有料プランのいずれかを購入されたユーザーは、ハイメモリ VM を提供状況に応じて利用できます。より高性能な GPU は、常にハイメモリ VM で提供されます。
# 次のコードセルを実行すれば、いつでも使用可能なメモリ量を確認できます。以下のコードセルを実行して「Not using a high-RAM runtime」と表示された場合は、メニューの <code>&#91;ランタイム&#93; &gt; &#91;ランタイムのタイプを変更&#93;</code> でハイメモリ ランタイムを有効にできます。ランタイムの仕様の切り替えボタンで &#91;ハイメモリ&#93; を選択します。その後、コードセルを再実行します。

# %%
import psutil

ram_gb = psutil.virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %% [markdown]
# ## より長時間の使用
#
# Colab のランタイムはすべて一定期間後にリセットされます（コードを実行していないランタイムはそれより早くリセットされます）。Colab Pro と Colab Pro+ のユーザーの場合、Colab を料金なしで利用しているユーザーよりもランタイムの接続時間が長くなります。
#
# ## バックグラウンド実行
#
# Colab Pro+ ユーザーは、バックグラウンド実行が可能です。バックグラウンド実行の場合、ブラウザタブを閉じた後も、ノートブックの実行が継続します。Pro+ のランタイムでは、使用できるコンピューティング ユニットがある限り、この機能は常に有効になります。

# %% [markdown]
# ## Colab Pro でのリソース制限の緩和
#
# Colab では利用できるリソースに制限があります。Colab を最大限に活用するには、リソースを有効に利用してください。たとえば、必要な場合にのみ GPU を使用し、作業が終了したら Colab のタブを閉じることで無駄な利用を避けられます。
#
# 制限に達した場合は、従量課金制のコンピューティング ユニットを購入することで、制限を緩和できます。<a href="https://colab.research.google.com/signup">従量課金制</a>でコンピューティング ユニットを購入するのは誰でも可能で、定期購入は不要です。

# %% [markdown]
# ## フィードバックのお願い
#
# <p>ご意見がございましたら、Google までお問い合わせください。フィードバックを送信する場合は、メニューから &#91;ヘルプ&#93; &gt; &#91;フィードバックを送信&#93; を選択してください。Colab Pro で使用量の上限に達した場合は、Pro+ を利用することをご検討ください。</p>
# <p>Colab Pro、Pro+ の請求（お支払い）または従量課金制に関してエラーやその他の問題が発生した場合は、<a href="mailto:colab-billing@google.com">colab-billing@google.com</a> までお問い合わせください。</p>

# %% [markdown]
# ## その他のリソース
#
# ### Colab でのノートブックの操作
# - [Colab の概要](/notebooks/basic_features_overview.ipynb)
# - [markdown のガイド](/notebooks/markdown_guide.ipynb)
# - [ライブラリのインポートと依存関係のインストール](/notebooks/snippets/importing_libraries.ipynb)
# - [GitHub でのノートブックの保存と読み込み](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [インタラクティブなフォーム](/notebooks/forms.ipynb)
# - [インタラクティブなウィジェット](/notebooks/widgets.ipynb)
#
# <a name="working-with-data"></a>
# ### データの操作
# - [データの読み込み: ドライブ、スプレッドシート、Google Cloud Storage](/notebooks/io.ipynb)
# - [グラフ: データの視覚化](/notebooks/charts.ipynb)
# - [BigQuery を使ってみる](/notebooks/bigquery.ipynb)
#
# ### 機械学習の集中講座
# Google の機械学習に関するオンライン コースからいくつかのノートブックをご紹介します。詳しくは、<a href="https://developers.google.com/machine-learning/crash-course/">全コースのウェブサイト</a>をご覧ください。
# - [Pandas DataFrame の概要](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [pandas を高速化する RAPIDS cuDF の概要](https://nvda.ws/rapids-cudf)
# - [cuML のアクセラレータ モードのスタートガイド](https://colab.research.google.com/github/rapidsai-community/showcase/blob/main/getting_started_tutorials/cuml_sklearn_colab_demo.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### アクセラレータの使用
# - [Flax NNX API を使用して MNIST データセットの手書き数字を分類するように CNN をトレーニングする](https://colab.research.google.com/github/google/flax/blob/main/docs_nnx/mnist_tutorial.ipynb)
# - [JAX を使用して画像分類用の Vision Transformer（ViT）をトレーニングする](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_Vision_transformer.ipynb)
# - [JAX を使用した Transformer 言語モデルによるテキスト分類](https://colab.research.google.com/github/jax-ml/jax-ai-stack/blob/main/docs/source/JAX_transformer_text_classification.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## 機械学習の例
#
# おすすめの例をご紹介します。
#
# - <a href="https://docs.jaxstack.ai/en/latest/JAX_for_LLM_pretraining.html">JAX AI スタックを使用して miniGPT 言語モデルをトレーニングする</a>
# - <a href="https://github.com/google/tunix/blob/main/examples/qlora_gemma.ipynb">Tunix を使用した LLM 向け LoRA / QLoRA のファインチューニング</a>
# - <a href="https://keras.io/examples/keras_recipes/parameter_efficient_finetuning_of_gemma_with_lora_and_qlora/">LoRA と QLoRA を使用した Gemma のパラメータ エフィシエント ファインチューニング</a>
# - <a href="https://keras.io/keras_hub/guides/hugging_face_keras_integration/">Hugging Face Transformers チェックポイントの読み込み</a>
# - <a href="https://keras.io/guides/int8_quantization_in_keras/">Keras での 8 ビット整数量子化</a>
# - <a href="https://keras.io/examples/keras_recipes/float8_training_and_inference_with_transformer/">シンプルな Transformer モデルを使用した Float8 のトレーニングと推論</a>
# - <a href="https://keras.io/keras_hub/guides/transformer_pretraining/">KerasHub を使用して Transformer をゼロから事前トレーニングする</a>
# - <a href="https://keras.io/examples/vision/mnist_convnet/">シンプルな MNIST convnet</a>
# - <a href="https://keras.io/examples/vision/image_classification_from_scratch/">Keras 3 を使用したゼロからの画像分類</a>
# - <a href="https://keras.io/keras_hub/guides/classification_with_keras_hub/">KerasHub を使用した画像分類</a>
